# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "weather_cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for latitudes,longitudes and cities
lat_lngs = []
cities = []

# Create sets of random latitude and longitude combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    if city not in cities:
        cities.append(city)

# Print city count
len(cities)

# %%
#Get city data
city_data = []
print("Beginning Data Retrieval     ")
print("-----------------------------")

for city in cities:
    query_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

#counters
record_count = 1
set_count = 1
# Loop
for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0
    # Create URLs
    city_url = query_url + "&q=" + city
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))
    # Add 1 to the record count
    record_count += 1
    #Create API request
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
    #If error, skip city
    except:
        print("City not found. Skipping...")
        pass
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | barrow
# Processing Record 2 of Set 1 | souillac
# Processing Record 3 of Set 1 | lebu
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | port blair
# Processing Record 6 of Set 1 | hithadhoo
# Processing Record 7 of Set 1 | batticaloa
# Processing Record 8 of Set 1 | longyearbyen
# Processing Record 9 of Set 1 | provideniya
# Processing Record 10 of Set 1 | cabo san lucas
# Processing Record 11 of Set 1 | bayir
# Processing Record 12 of Set 1 | busselton
# Processing Record 13 of Set 1 | candelaria
# Processing Record 14 of Set 1 | dikson
# Processing Record 15 of Set 1 | hobart
# Processing Record 16 of Set 1 | cockburn harbour
# City not found. Skipping...
# Processing Record 17 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | sandpoint
# Processing Record 20 of Set 1 | albany
# Processing Record 21 of Set 1 | avarua
# Processing Record 22 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 23 of Set 1 | hasaki
# Processing Record 24 of Set 1 | punta arenas
# Processing Record 25 of Set 1 | puerto ayora
# Processing Record 26 of Set 1 | airai
# Processing Record 27 of Set 1 | boali
# Processing Record 28 of Set 1 | tuktoyaktuk
# Processing Record 29 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 30 of Set 1 | hilo
# Processing Record 31 of Set 1 | naze
# Processing Record 32 of Set 1 | fortuna
# Processing Record 33 of Set 1 | iralaya
# Processing Record 34 of Set 1 | butaritari
# Processing Record 35 of Set 1 | mataura
# Processing Record 36 of Set 1 | cayenne
# Processing Record 37 of Set 1 | port alfred
# Processing Record 38 of Set 1 | tevaitoa
# Processing Record 39 of Set 1 | port lincoln
# Processing Record 40 of Set 1 | joinville
# Processing Record 41 of Set 1 | batagay
# Processing Record 42 of Set 1 | pisco
# Processing Record 43 of Set 1 | bethel
# Processing Record 44 of Set 1 | bangkalan
# Processing Record 45 of Set 1 | jizan
# Processing Record 46 of Set 1 | severo-kurilsk
# Processing Record 47 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 1 | christchurch
# Processing Record 49 of Set 1 | port elizabeth
# Processing Record 50 of Set 1 | east london
# Processing Record 0 of Set 2 | clyde river
# Processing Record 1 of Set 2 | codrington
# Processing Record 2 of Set 2 | ambon
# Processing Record 3 of Set 2 | torbay
# Processing Record 4 of Set 2 | ilulissat
# Processing Record 5 of Set 2 | atuona
# Processing Record 6 of Set 2 | mercedes
# Processing Record 7 of Set 2 | nastola
# Processing Record 8 of Set 2 | nioki
# Processing Record 9 of Set 2 | kodiak
# Processing Record 10 of Set 2 | haines junction
# Processing Record 11 of Set 2 | chokurdakh
# Processing Record 12 of Set 2 | kovur
# Processing Record 13 of Set 2 | grand gaube
# Processing Record 14 of Set 2 | guerrero negro
# Processing Record 15 of Set 2 | chuy
# Processing Record 16 of Set 2 | thompson
# Processing Record 17 of Set 2 | hermanus
# Processing Record 18 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 19 of Set 2 | carnarvon
# Processing Record 20 of Set 2 | zhitikara
# City not found. Skipping...
# Processing Record 21 of Set 2 | bilibino
# Processing Record 22 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 2 | cape town
# Processing Record 24 of Set 2 | new norfolk
# Processing Record 25 of Set 2 | dharchula
# Processing Record 26 of Set 2 | sisimiut
# Processing Record 27 of Set 2 | flin flon
# Processing Record 28 of Set 2 | khandyga
# Processing Record 29 of Set 2 | upernavik
# Processing Record 30 of Set 2 | mar del plata
# Processing Record 31 of Set 2 | lompoc
# Processing Record 32 of Set 2 | shu
# Processing Record 33 of Set 2 | bluff
# Processing Record 34 of Set 2 | zelenoborsk
# Processing Record 35 of Set 2 | karratha
# Processing Record 36 of Set 2 | batagay-alyta
# Processing Record 37 of Set 2 | bambous virieux
# Processing Record 38 of Set 2 | hami
# Processing Record 39 of Set 2 | castro
# Processing Record 40 of Set 2 | mount gambier
# Processing Record 41 of Set 2 | kruisfontein
# Processing Record 42 of Set 2 | wanning
# Processing Record 43 of Set 2 | roald
# Processing Record 44 of Set 2 | lata
# Processing Record 45 of Set 2 | bredasdorp
# Processing Record 46 of Set 2 | cabedelo
# Processing Record 47 of Set 2 | yellowknife
# Processing Record 48 of Set 2 | kapaa
# Processing Record 49 of Set 2 | coihaique
# Processing Record 0 of Set 3 | khatanga
# Processing Record 1 of Set 3 | kidal
# Processing Record 2 of Set 3 | polunochnoye
# Processing Record 3 of Set 3 | constitucion
# Processing Record 4 of Set 3 | borogontsy
# Processing Record 5 of Set 3 | malartic
# Processing Record 6 of Set 3 | bamako
# Processing Record 7 of Set 3 | rudbar
# Processing Record 8 of Set 3 | general roca
# Processing Record 9 of Set 3 | georgetown
# Processing Record 10 of Set 3 | strezhevoy
# Processing Record 11 of Set 3 | moba
# Processing Record 12 of Set 3 | saskylakh
# Processing Record 13 of Set 3 | bayji
# Processing Record 14 of Set 3 | esperance
# Processing Record 15 of Set 3 | faya
# Processing Record 16 of Set 3 | ponta do sol
# Processing Record 17 of Set 3 | shingu
# Processing Record 18 of Set 3 | novyy urengoy
# Processing Record 19 of Set 3 | erenhot
# Processing Record 20 of Set 3 | lujan
# Processing Record 21 of Set 3 | novo aripuana
# Processing Record 22 of Set 3 | nelson bay
# Processing Record 23 of Set 3 | saint-philippe
# Processing Record 24 of Set 3 | vaini
# Processing Record 25 of Set 3 | egvekinot
# Processing Record 26 of Set 3 | lensk
# Processing Record 27 of Set 3 | lavrentiya
# Processing Record 28 of Set 3 | alta floresta
# Processing Record 29 of Set 3 | soyo
# Processing Record 30 of Set 3 | poum
# Processing Record 31 of Set 3 | manjacaze
# Processing Record 32 of Set 3 | pokaran
# Processing Record 33 of Set 3 | hereford
# Processing Record 34 of Set 3 | neryungri
# Processing Record 35 of Set 3 | grand-lahou
# Processing Record 36 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 37 of Set 3 | port hardy
# Processing Record 38 of Set 3 | ipixuna
# Processing Record 39 of Set 3 | cidreira
# Processing Record 40 of Set 3 | laguna
# Processing Record 41 of Set 3 | beyneu
# Processing Record 42 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 43 of Set 3 | nikolskoye
# Processing Record 44 of Set 3 | victoria
# Processing Record 45 of Set 3 | vestmanna
# Processing Record 46 of Set 3 | sim
# Processing Record 47 of Set 3 | katsuura
# Processing Record 48 of Set 3 | telfs
# Processing Record 49 of Set 3 | humaita
# Processing Record 0 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 1 of Set 4 | korla
# Processing Record 2 of Set 4 | pareora
# Processing Record 3 of Set 4 | povenets
# Processing Record 4 of Set 4 | saint george
# Processing Record 5 of Set 4 | bandarbeyla
# Processing Record 6 of Set 4 | santa vitoria do palmar
# Processing Record 7 of Set 4 | talnakh
# Processing Record 8 of Set 4 | santa marta
# Processing Record 9 of Set 4 | machali
# Processing Record 10 of Set 4 | dunedin
# Processing Record 11 of Set 4 | jamestown
# Processing Record 12 of Set 4 | cherskiy
# Processing Record 13 of Set 4 | lasa
# Processing Record 14 of Set 4 | abu dhabi
# Processing Record 15 of Set 4 | luderitz
# Processing Record 16 of Set 4 | yichang
# Processing Record 17 of Set 4 | araouane
# Processing Record 18 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 19 of Set 4 | xining
# Processing Record 20 of Set 4 | jiddah
# City not found. Skipping...
# Processing Record 21 of Set 4 | chegdomyn
# Processing Record 22 of Set 4 | merauke
# Processing Record 23 of Set 4 | padang
# Processing Record 24 of Set 4 | kizukuri
# Processing Record 25 of Set 4 | nabire
# Processing Record 26 of Set 4 | kaitangata
# Processing Record 27 of Set 4 | norman wells
# Processing Record 28 of Set 4 | nagua
# Processing Record 29 of Set 4 | tamiahua
# Processing Record 30 of Set 4 | san patricio
# Processing Record 31 of Set 4 | ahipara
# Processing Record 32 of Set 4 | henties bay
# Processing Record 33 of Set 4 | caravelas
# Processing Record 34 of Set 4 | iqaluit
# Processing Record 35 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 36 of Set 4 | srednekolymsk
# Processing Record 37 of Set 4 | sidi qasim
# City not found. Skipping...
# Processing Record 38 of Set 4 | porangatu
# Processing Record 39 of Set 4 | ozgon
# City not found. Skipping...
# Processing Record 40 of Set 4 | yuli
# Processing Record 41 of Set 4 | leningradskiy
# Processing Record 42 of Set 4 | kavieng
# Processing Record 43 of Set 4 | wamba
# Processing Record 44 of Set 4 | pevek
# Processing Record 45 of Set 4 | papetoai
# Processing Record 46 of Set 4 | ust-kuyga
# Processing Record 47 of Set 4 | vieste
# Processing Record 48 of Set 4 | asfi
# Processing Record 49 of Set 4 | yar-sale
# Processing Record 0 of Set 5 | tasbuget
# City not found. Skipping...
# Processing Record 1 of Set 5 | qaanaaq
# Processing Record 2 of Set 5 | tasiilaq
# Processing Record 3 of Set 5 | cervo
# Processing Record 4 of Set 5 | mason city
# Processing Record 5 of Set 5 | tabou
# Processing Record 6 of Set 5 | opuwo
# Processing Record 7 of Set 5 | samsun
# Processing Record 8 of Set 5 | lovington
# Processing Record 9 of Set 5 | kibaya
# Processing Record 10 of Set 5 | quimper
# Processing Record 11 of Set 5 | marawi
# Processing Record 12 of Set 5 | samfya
# Processing Record 13 of Set 5 | samoded
# Processing Record 14 of Set 5 | kaitong
# Processing Record 15 of Set 5 | nakamura
# Processing Record 16 of Set 5 | mahebourg
# Processing Record 17 of Set 5 | sokoto
# Processing Record 18 of Set 5 | muros
# Processing Record 19 of Set 5 | aakirkeby
# City not found. Skipping...
# Processing Record 20 of Set 5 | mayor pablo lagerenza
# Processing Record 21 of Set 5 | kollumerland
# City not found. Skipping...
# Processing Record 22 of Set 5 | sakakah
# Processing Record 23 of Set 5 | amapa
# Processing Record 24 of Set 5 | dingle
# Processing Record 25 of Set 5 | langsa
# Processing Record 26 of Set 5 | wewak
# Processing Record 27 of Set 5 | yulara
# Processing Record 28 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 29 of Set 5 | teya
# Processing Record 30 of Set 5 | geraldton
# Processing Record 31 of Set 5 | tuatapere
# Processing Record 32 of Set 5 | santiago de las vegas
# Processing Record 33 of Set 5 | quatre cocos
# Processing Record 34 of Set 5 | petrolina de goias
# Processing Record 35 of Set 5 | umm lajj
# Processing Record 36 of Set 5 | sitka
# Processing Record 37 of Set 5 | sibolga
# Processing Record 38 of Set 5 | faanui
# Processing Record 39 of Set 5 | alekseyevsk
# Processing Record 40 of Set 5 | mogadishu
# Processing Record 41 of Set 5 | bethanien
# Processing Record 42 of Set 5 | high level
# Processing Record 43 of Set 5 | san cristobal
# Processing Record 44 of Set 5 | cockburn town
# Processing Record 45 of Set 5 | usinsk
# Processing Record 46 of Set 5 | ribeira grande
# Processing Record 47 of Set 5 | lucea
# Processing Record 48 of Set 5 | contai
# Processing Record 49 of Set 5 | nema
# Processing Record 0 of Set 6 | los alamos
# Processing Record 1 of Set 6 | yuxia
# Processing Record 2 of Set 6 | podor
# Processing Record 3 of Set 6 | morococha
# Processing Record 4 of Set 6 | tongliao
# Processing Record 5 of Set 6 | moree
# Processing Record 6 of Set 6 | tazmalt
# Processing Record 7 of Set 6 | sao gabriel da cachoeira
# Processing Record 8 of Set 6 | nkhotakota
# Processing Record 9 of Set 6 | pinehurst
# Processing Record 10 of Set 6 | rokytne
# Processing Record 11 of Set 6 | qasigiannguit
# Processing Record 12 of Set 6 | marsh harbour
# Processing Record 13 of Set 6 | nantucket
# Processing Record 14 of Set 6 | klaksvik
# Processing Record 15 of Set 6 | vietri sul mare
# Processing Record 16 of Set 6 | ust-nera
# Processing Record 17 of Set 6 | dianopolis
# City not found. Skipping...
# Processing Record 18 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 6 | stephenville
# Processing Record 20 of Set 6 | sao miguel do tapuio
# Processing Record 21 of Set 6 | warmbad
# Processing Record 22 of Set 6 | athabasca
# Processing Record 23 of Set 6 | lakatoro
# Processing Record 24 of Set 6 | kieta
# Processing Record 25 of Set 6 | te anau
# Processing Record 26 of Set 6 | ostrovnoy
# Processing Record 27 of Set 6 | taicheng
# Processing Record 28 of Set 6 | flinders
# Processing Record 29 of Set 6 | bilma
# Processing Record 30 of Set 6 | catamarca
# Processing Record 31 of Set 6 | mastic beach
# Processing Record 32 of Set 6 | catalao
# Processing Record 33 of Set 6 | krutinka
# Processing Record 34 of Set 6 | jaru
# Processing Record 35 of Set 6 | acari
# Processing Record 36 of Set 6 | mocambique
# City not found. Skipping...
# Processing Record 37 of Set 6 | narsaq
# Processing Record 38 of Set 6 | asgabat
# Processing Record 39 of Set 6 | pennagaram
# Processing Record 40 of Set 6 | haibowan
# City not found. Skipping...
# Processing Record 41 of Set 6 | okha
# Processing Record 42 of Set 6 | ajdabiya
# Processing Record 43 of Set 6 | palmer
# Processing Record 44 of Set 6 | along
# Processing Record 45 of Set 6 | yagoua
# Processing Record 46 of Set 6 | enniscorthy
# Processing Record 47 of Set 6 | turan
# Processing Record 48 of Set 6 | karakol
# Processing Record 49 of Set 6 | gilgit
# Processing Record 0 of Set 7 | ponta delgada
# Processing Record 1 of Set 7 | asau
# Processing Record 2 of Set 7 | yamada
# Processing Record 3 of Set 7 | biak
# Processing Record 4 of Set 7 | balkanabat
# Processing Record 5 of Set 7 | adrar
# Processing Record 6 of Set 7 | kashan
# Processing Record 7 of Set 7 | huarmey
# Processing Record 8 of Set 7 | taoudenni
# Processing Record 9 of Set 7 | ilheus
# Processing Record 10 of Set 7 | buala
# Processing Record 11 of Set 7 | evanston
# Processing Record 12 of Set 7 | arraial do cabo
# Processing Record 13 of Set 7 | odienne
# Processing Record 14 of Set 7 | portland
# Processing Record 15 of Set 7 | nemuro
# Processing Record 16 of Set 7 | makakilo city
# Processing Record 17 of Set 7 | ancud
# Processing Record 18 of Set 7 | ariquemes
# Processing Record 19 of Set 7 | horta
# Processing Record 20 of Set 7 | tecoanapa
# Processing Record 21 of Set 7 | kristiinankaupunki
# Processing Record 22 of Set 7 | sal rei
# Processing Record 23 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 24 of Set 7 | lewiston
# Processing Record 25 of Set 7 | starkville
# Processing Record 26 of Set 7 | dire dawa
# Processing Record 27 of Set 7 | vila
# Processing Record 28 of Set 7 | hamilton
# Processing Record 29 of Set 7 | san quintin
# Processing Record 30 of Set 7 | komsomolskiy
# Processing Record 31 of Set 7 | solwezi
# Processing Record 32 of Set 7 | tiksi
# Processing Record 33 of Set 7 | sanbu
# Processing Record 34 of Set 7 | lagoa
# Processing Record 35 of Set 7 | ushirombo
# Processing Record 36 of Set 7 | bengkulu
# Processing Record 37 of Set 7 | inirida
# Processing Record 38 of Set 7 | ulaangom
# Processing Record 39 of Set 7 | alice springs
# Processing Record 40 of Set 7 | oyama
# Processing Record 41 of Set 7 | kyzyl-suu
# Processing Record 42 of Set 7 | suez
# Processing Record 43 of Set 7 | haverhill
# Processing Record 44 of Set 7 | kloulklubed
# Processing Record 45 of Set 7 | broken hill
# Processing Record 46 of Set 7 | malindi
# Processing Record 47 of Set 7 | kutum
# Processing Record 48 of Set 7 | skeldon
# Processing Record 49 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 0 of Set 8 | nador
# Processing Record 1 of Set 8 | katha
# City not found. Skipping...
# Processing Record 2 of Set 8 | makamba
# Processing Record 3 of Set 8 | husavik
# Processing Record 4 of Set 8 | bereda
# Processing Record 5 of Set 8 | charlestown
# Processing Record 6 of Set 8 | carutapera
# Processing Record 7 of Set 8 | pyapon
# Processing Record 8 of Set 8 | la ronge
# Processing Record 9 of Set 8 | baiyin
# Processing Record 10 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 8 | sioux lookout
# Processing Record 12 of Set 8 | maarianhamina
# Processing Record 13 of Set 8 | benguela
# Processing Record 14 of Set 8 | arman
# Processing Record 15 of Set 8 | muli
# Processing Record 16 of Set 8 | nuuk
# Processing Record 17 of Set 8 | comodoro rivadavia
# Processing Record 18 of Set 8 | northam
# Processing Record 19 of Set 8 | farmington
# Processing Record 20 of Set 8 | sao filipe
# Processing Record 21 of Set 8 | maceio
# Processing Record 22 of Set 8 | pangnirtung
# Processing Record 23 of Set 8 | salalah
# Processing Record 24 of Set 8 | corcoran
# Processing Record 25 of Set 8 | nome
# Processing Record 26 of Set 8 | omsukchan
# Processing Record 27 of Set 8 | kushmurun
# Processing Record 28 of Set 8 | del rio
# Processing Record 29 of Set 8 | bubaque
# Processing Record 30 of Set 8 | kumbo
# Processing Record 31 of Set 8 | meulaboh
# Processing Record 32 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 33 of Set 8 | vila velha
# Processing Record 34 of Set 8 | kailua
# Processing Record 35 of Set 8 | sao felix do xingu
# Processing Record 36 of Set 8 | oshkosh
# Processing Record 37 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 38 of Set 8 | artyom
# Processing Record 39 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 8 | aktau
# Processing Record 41 of Set 8 | bam
# Processing Record 42 of Set 8 | smoky lake
# Processing Record 43 of Set 8 | tuy hoa
# Processing Record 44 of Set 8 | lorengau
# Processing Record 45 of Set 8 | la gomera
# Processing Record 46 of Set 8 | krasnoselkup
# Processing Record 47 of Set 8 | behat
# Processing Record 48 of Set 8 | kurumkan
# Processing Record 49 of Set 8 | estacion coahuila
# Processing Record 0 of Set 9 | progreso
# Processing Record 1 of Set 9 | kuala terengganu
# Processing Record 2 of Set 9 | homer
# Processing Record 3 of Set 9 | svarstad
# Processing Record 4 of Set 9 | almenara
# Processing Record 5 of Set 9 | plettenberg bay
# Processing Record 6 of Set 9 | togur
# Processing Record 7 of Set 9 | sorland
# Processing Record 8 of Set 9 | itoman
# Processing Record 9 of Set 9 | sorong
# Processing Record 10 of Set 9 | jipijapa
# Processing Record 11 of Set 9 | labutta
# City not found. Skipping...
# Processing Record 12 of Set 9 | kavaratti
# Processing Record 13 of Set 9 | daxian
# City not found. Skipping...
# Processing Record 14 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 15 of Set 9 | mankovo-kalitvenskoye
# City not found. Skipping...
# Processing Record 16 of Set 9 | campo formoso
# Processing Record 17 of Set 9 | fort nelson
# Processing Record 18 of Set 9 | smithers
# Processing Record 19 of Set 9 | muskogee
# Processing Record 20 of Set 9 | riwaka
# Processing Record 21 of Set 9 | amga
# Processing Record 22 of Set 9 | shetpe
# Processing Record 23 of Set 9 | kununurra
# Processing Record 24 of Set 9 | guiyang
# Processing Record 25 of Set 9 | jieshi
# Processing Record 26 of Set 9 | bathsheba
# Processing Record 27 of Set 9 | half moon bay
# Processing Record 28 of Set 9 | fairbanks
# Processing Record 29 of Set 9 | hope
# Processing Record 30 of Set 9 | bentiu
# Processing Record 31 of Set 9 | tommot
# Processing Record 32 of Set 9 | luganville
# Processing Record 33 of Set 9 | ocho rios
# Processing Record 34 of Set 9 | rawa mazowiecka
# Processing Record 35 of Set 9 | kimbe
# Processing Record 36 of Set 9 | vardo
# Processing Record 37 of Set 9 | grindavik
# Processing Record 38 of Set 9 | chicama
# Processing Record 39 of Set 9 | kuytun
# Processing Record 40 of Set 9 | nekrasovskaya
# Processing Record 41 of Set 9 | seoul
# Processing Record 42 of Set 9 | nanortalik
# Processing Record 43 of Set 9 | ayios kirikos
# City not found. Skipping...
# Processing Record 44 of Set 9 | doha
# Processing Record 45 of Set 9 | eirunepe
# Processing Record 46 of Set 9 | nuevo progreso
# Processing Record 47 of Set 9 | san jose
# Processing Record 48 of Set 9 | honiara
# Processing Record 49 of Set 9 | jalingo
# Processing Record 0 of Set 10 | akdepe
# Processing Record 1 of Set 10 | iquitos
# Processing Record 2 of Set 10 | batemans bay
# Processing Record 3 of Set 10 | natal
# Processing Record 4 of Set 10 | devonport
# Processing Record 5 of Set 10 | sayaxche
# Processing Record 6 of Set 10 | qingyuan
# Processing Record 7 of Set 10 | bogolyubovo
# Processing Record 8 of Set 10 | luanda
# Processing Record 9 of Set 10 | esso
# Processing Record 10 of Set 10 | viransehir
# Processing Record 11 of Set 10 | techiman
# Processing Record 12 of Set 10 | moyale
# Processing Record 13 of Set 10 | zhezkazgan
# Processing Record 14 of Set 10 | dalvik
# Processing Record 15 of Set 10 | dicabisagan
# Processing Record 16 of Set 10 | altay
# Processing Record 17 of Set 10 | terrenate
# Processing Record 18 of Set 10 | artigas
# Processing Record 19 of Set 10 | maltahohe
# Processing Record 20 of Set 10 | lazaro cardenas
# Processing Record 21 of Set 10 | chapais
# Processing Record 22 of Set 10 | tondano
# Processing Record 23 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 10 | saldanha
# Processing Record 25 of Set 10 | marstal
# Processing Record 26 of Set 10 | ixtapa
# Processing Record 27 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 28 of Set 10 | mirabad
# Processing Record 29 of Set 10 | shaghat
# Processing Record 30 of Set 10 | kandrian
# Processing Record 31 of Set 10 | belmonte
# Processing Record 32 of Set 10 | wenling
# Processing Record 33 of Set 10 | buraydah
# Processing Record 34 of Set 10 | asayita
# City not found. Skipping...
# Processing Record 35 of Set 10 | hofn
# Processing Record 36 of Set 10 | carauari
# Processing Record 37 of Set 10 | santona
# Processing Record 38 of Set 10 | kahului
# Processing Record 39 of Set 10 | toplet
# Processing Record 40 of Set 10 | kultuk
# Processing Record 41 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 42 of Set 10 | anadyr
# Processing Record 43 of Set 10 | saint anthony
# Processing Record 44 of Set 10 | timberlake
# Processing Record 45 of Set 10 | kamennogorsk
# Processing Record 46 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 47 of Set 10 | manta
# Processing Record 48 of Set 10 | pachperwa
# Processing Record 49 of Set 10 | vao
# Processing Record 0 of Set 11 | deputatskiy
# Processing Record 1 of Set 11 | fereydun kenar
# Processing Record 2 of Set 11 | huangyan
# Processing Record 3 of Set 11 | kurilsk
# Processing Record 4 of Set 11 | lithakia
# Processing Record 5 of Set 11 | jauharabad
# Processing Record 6 of Set 11 | berlevag
# Processing Record 7 of Set 11 | margate
# Processing Record 8 of Set 11 | mindif
# Processing Record 9 of Set 11 | makurdi
# Processing Record 10 of Set 11 | aklavik
# Processing Record 11 of Set 11 | ardea
# Processing Record 12 of Set 11 | tirumullaivasal
# Processing Record 13 of Set 11 | suratgarh
# Processing Record 14 of Set 11 | tineo
# Processing Record 15 of Set 11 | banda aceh
# Processing Record 16 of Set 11 | bundaberg
# Processing Record 17 of Set 11 | lerwick
# Processing Record 18 of Set 11 | marystown
# Processing Record 19 of Set 11 | ciudad bolivar
# Processing Record 20 of Set 11 | carmona
# Processing Record 21 of Set 11 | minas
# Processing Record 22 of Set 11 | astipalaia
# City not found. Skipping...
# Processing Record 23 of Set 11 | bluefields
# Processing Record 24 of Set 11 | rajapur
# Processing Record 25 of Set 11 | liku
# Processing Record 26 of Set 11 | douglas
# Processing Record 27 of Set 11 | alcaniz
# Processing Record 28 of Set 11 | awjilah
# Processing Record 29 of Set 11 | zeya
# Processing Record 30 of Set 11 | honningsvag
# Processing Record 31 of Set 11 | gamba
# Processing Record 32 of Set 11 | rayadrug
# Processing Record 33 of Set 11 | gannan
# Processing Record 34 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 35 of Set 11 | ahome
# Processing Record 36 of Set 11 | pochutla
# Processing Record 37 of Set 11 | mingaora
# Processing Record 38 of Set 11 | samarai
# Processing Record 39 of Set 11 | rodino
# Processing Record 40 of Set 11 | linjiang
# Processing Record 41 of Set 11 | deder
# Processing Record 42 of Set 11 | crotone
# Processing Record 43 of Set 11 | sampit
# Processing Record 44 of Set 11 | susanville
# Processing Record 45 of Set 11 | soe
# Processing Record 46 of Set 11 | puerto leguizamo
# Processing Record 47 of Set 11 | loandjili
# Processing Record 48 of Set 11 | chaihe
# Processing Record 49 of Set 11 | kabo
# Processing Record 0 of Set 12 | marrakesh
# Processing Record 1 of Set 12 | mutare
# Processing Record 2 of Set 12 | gazanjyk
# Processing Record 3 of Set 12 | skjervoy
# Processing Record 4 of Set 12 | port shepstone
# Processing Record 5 of Set 12 | skelleftea
# Processing Record 6 of Set 12 | lima
# Processing Record 7 of Set 12 | broome
# Processing Record 8 of Set 12 | axim
# Processing Record 9 of Set 12 | campoverde
# Processing Record 10 of Set 12 | baker city
# Processing Record 11 of Set 12 | acarau
# Processing Record 12 of Set 12 | sentyabrskiy
# City not found. Skipping...
# Processing Record 13 of Set 12 | palencia
# Processing Record 14 of Set 12 | wagar
# Processing Record 15 of Set 12 | namatanai
# Processing Record 16 of Set 12 | pandan
# Processing Record 17 of Set 12 | beni suef
# Processing Record 18 of Set 12 | french harbor
# Processing Record 19 of Set 12 | pingliang
# Processing Record 20 of Set 12 | baykit
# Processing Record 21 of Set 12 | urubicha
# Processing Record 22 of Set 12 | susangerd
# Processing Record 23 of Set 12 | solec kujawski
# Processing Record 24 of Set 12 | lamu
# Processing Record 25 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 26 of Set 12 | rawson
# Processing Record 27 of Set 12 | port augusta
# Processing Record 28 of Set 12 | areka
# Processing Record 29 of Set 12 | barranca
# Processing Record 30 of Set 12 | aksarka
# Processing Record 31 of Set 12 | tokur
# Processing Record 32 of Set 12 | taksimo
# Processing Record 33 of Set 12 | vestbygda
# City not found. Skipping...
# Processing Record 34 of Set 12 | preobrazheniye
# Processing Record 35 of Set 12 | nautla
# Processing Record 36 of Set 12 | ardakan
# Processing Record 37 of Set 12 | udachnyy
# Processing Record 38 of Set 12 | moroni
# Processing Record 39 of Set 12 | baglan
# Processing Record 40 of Set 12 | bonthe
# Processing Record 41 of Set 12 | harper
# Processing Record 42 of Set 12 | inhambane
# Processing Record 43 of Set 12 | nishihara
# Processing Record 44 of Set 12 | mandiana
# Processing Record 45 of Set 12 | erzin
# Processing Record 46 of Set 12 | ambovombe
# Processing Record 47 of Set 12 | esquipulas palo gordo
# Processing Record 48 of Set 12 | den helder
# Processing Record 49 of Set 12 | kazerun
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
weather_data = pd.DataFrame(city_data)

weather_data

# %%
weather_data.to_csv(output_data_file)

# %%
dif_weather_data = weather_data[(weather_data["Humidity"] > 100)].index
dif_weather_data

# %%
new_weather_data = weather_data[weather_data["Humidity"].isin(dif_weather_data)==False] 
new_weather_data

# %%
new_weather_data.csv(output_data_file)

# %%
#Latitude vs Max Temp
plt.scatter(weather_data["Lat"],weather_data["Max Temp"],edgecolors='b')
plt.title(f"City Latitude vs. Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature °F")
plt.grid()
plt.xlim((-90,90))
plt.show

# %%
#Latitude vs Humidity
plt.scatter(weather_data["Lat"],weather_data["Humidity"],edgecolors='b')
plt.title(f"City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.grid()
plt.xlim((-90,90))
plt.show

# %%
#Latitude vs Cloudiness
plt.scatter(weather_data["Lat"],weather_data["Cloudiness"],edgecolors='b')
plt.title(f"City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.grid()
plt.xlim((-90,90))
plt.show

# %%
#Latitude vs Wind Speed
plt.scatter(weather_data["Lat"],weather_data["Wind Speed"],edgecolors='b')
plt.title(f"City Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.grid()
plt.xlim((-90,90))
plt.show

# %%
northern_cities = weather_data[weather_data.Lat > 0]
northern_cities.head()

# %%
southern_cities = weather_data[weather_data.Lat < 0]
southern_cities.head()

# %%
#Northern cities latitude and max temp regression
x_values = northern_cities["Lat"]
y_values = northern_cities["Max Temp"]

plt.scatter(x_values,y_values,edgecolors='b')
plt.xlabel("Latitude")
plt.ylabel("Max Temperature °F")
plt.xlim((0,90))
slope, intercept, r_value, p_value, std_err = linregress(x_values,y_values)
plt.plot(x_values, intercept + slope*x_values, 'r')
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(2,min(y_values)),fontsize=13,color="red")
plt.title(f"Northern Hemisphere Max Temperature vs. Latitude")

print(f"The r-squared is {r_value * r_value}")
plt.show

# %%
#Southern cities latitude and max temp regression
x_values = southern_cities["Lat"]
y_values = southern_cities["Max Temp"]

plt.scatter(x_values,y_values,edgecolors='b')
plt.xlabel("Latitude")
plt.ylabel("Max Temperature °F")
plt.xlim((-90,0))
slope, intercept, r_value, p_value, std_err = linregress(x_values,y_values)
plt.plot(x_values, intercept + slope*x_values, 'r')
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(-90,min(y_values)),fontsize=13,color="red")
plt.title(f"Southern Hemisphere Max Temperature vs. Latitude")
print(f"The r-squared is {r_value * r_value}")
plt.show

# %%
#Northern cities latitude and humidity regression
x_values = northern_cities["Lat"]
y_values = northern_cities["Humidity"]

plt.scatter(x_values,y_values,edgecolors='b')
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.xlim((0,90))
plt.ylim((0,100))
slope, intercept, r_value, p_value, std_err = linregress(x_values,y_values)
plt.plot(x_values, intercept + slope*x_values, 'r')
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(3,min(y_values)),fontsize=13,color="red")
plt.title(f"Northern Hemisphere Humidity vs. Latitude")
print(f"The r-squared is {r_value * r_value}")
plt.show

# %%
#Southern cities latitude and humidity regression
x_values = southern_cities["Lat"]
y_values = southern_cities["Humidity"]

plt.scatter(x_values,y_values,edgecolors='b')
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.xlim((-90,0))
plt.ylim((100,0))
slope, intercept, r_value, p_value, std_err = linregress(x_values,y_values)
plt.plot(x_values, intercept + slope*x_values, 'r')
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(3,min(y_values)),fontsize=13,color="red")
plt.title(f"Southern Hemisphere Humidity vs. Latitude")
print(f"The r-squared is {r_value * r_value}")
plt.show

# %%
#Northern cities latitude and cloudiness regression
x_values = northern_cities["Cloudiness"]
y_values = northern_cities["Lat"]

plt.scatter(x_values,y_values,edgecolors='b')
plt.xlabel("Cloudiness")
plt.ylabel("Latitude")
plt.xlim((0,90))
plt.ylim((-5,100))
slope, intercept, r_value, p_value, std_err = linregress(x_values,y_values)
plt.plot(x_values, intercept + slope*x_values, 'r')
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(90,min(y_values)),fontsize=13,color="red")
plt.title(f"Northern Hemisphere Cloudiness vs. Latitude")
print(f"The r-squared is {r_value * r_value}")
plt.show

# %%
#Southern cities latitude and cloudiness regression

x_values = southern_cities["Cloudiness"]
y_values = southern_cities["Lat"]

plt.scatter(x_values,y_values,edgecolors='b')
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.xlim((-90,120))
plt.ylim((-80,100))
slope, intercept, r_value, p_value, std_err = linregress(x_values,y_values)
plt.plot(x_values, intercept + slope*x_values, 'r')
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(-90,min(y_values)),fontsize=13,color="red")
plt.title(f"Southern Hemisphere Cloudiness vs. Latitude")
print(f"The r-squared is {r_value * r_value}")
plt.show

# %%
#Northern cities latitude and wind speed regression
x_values = northern_cities["Lat"]
y_values = northern_cities["Wind Speed"]

plt.scatter(x_values,y_values,edgecolors='b')
plt.xlabel("Wind Speed")
plt.ylabel("Latitude")
plt.xlim((0,90))
slope, intercept, r_value, p_value, std_err = linregress(x_values,y_values)
plt.plot(x_values, intercept + slope*x_values, 'r')
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(5,min(y_values)),fontsize=13,color="red")
plt.title(f"Northern Hemisphere Wind Speed vs. Latitude")
print(f"The r-squared is {r_value * r_value}")
plt.show

# %%
#Southern cities latitude and wind speed regression
x_values = southern_cities["Lat"]
y_values = southern_cities["Wind Speed"]

plt.scatter(x_values,y_values,edgecolors='b')
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.xlim((0,90))
slope, intercept, r_value, p_value, std_err = linregress(x_values,y_values)
plt.plot(x_values, intercept + slope*x_values, 'r')
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(50,min(y_values)),fontsize=13,color="red")
plt.title(f"Southern Hemisphere Wind Speed vs. Latitude")
print(f"The r-squared is {r_value * r_value}")
plt.show
